# %% [markdown]
# 4. Add a filter to your dashboard (e.g., by region or date range) and confirm both visualizations respond
# to it.
#
# -->>
#
# The dashboard i created for basic task is too simple soo that i picked up one prevoiusly made dashboard which is TPCH Business Analytics Dashboard.
# using the filtering and performing the other task on it.
#
# ## Dashboard Filters
#
# Three global filters were added to the dashboard to make the analysis interactive:
#
# 1. **Order Date Range** – filters the dashboard data based on the selected order date range.
# 2. **Order Priority** – filters the data based on the selected order priority.
# 3. **Customer by Segment** – filters the data based on the selected customer segment.
#
# The filters were tested by selecting different values and confirming that the dashboard visualizations updated accordingly.
#
# This allows users to interactively analyze the dashboard based on date, order priority, and customer segment.
#
# ![image_1789451324258.png](./image_1789451324258.png "image_1789451324258.png")

# %% [markdown]
# 5. Set up a Genie Agent scoped to your sales tables: write at least 2 instructions and 2 sample queries to steer its behavior.
#
# -->>
# %md
#
# ## TPCH Genie Agent
#
# A Genie Agent was created and configured using the TPCH data for business analytics.
#
# The Agent was scoped to the relevant TPCH tables and connected to a SQL Warehouse for query execution.
#
# ### Instructions Added
#
# 1. Use the configured TPCH tables as the primary data sources for answering business questions.
#
# 2. When calculating revenue, use the appropriate line item price and discount fields and aggregate the calculated revenue using SUM.
#
# 3. When analyzing sales trends, use the order date and group the results by month unless another time period is requested.
#
# ### Sample Queries Added
#
# 1. **Which customer generated the highest revenue?**
#
# 2. **What is the monthly revenue trend?**
#
# These instructions and sample queries help guide the Genie Agent to understand the TPCH data and generate more relevant SQL for business questions.
#
# The Agent was also tested with natural-language questions to verify that it could generate SQL and return the expected results.
#
# ### Below tha Agent Monitor page image for refferance
# ![image_1789463107654.png](./image_1789463107654.png "image_1789463107654.png")

# %% [markdown]
# 6. Ask your Genie Agent a question it initially answers incorrectly or vaguely, then improve its instructions/sample queries/trusted assets until it answers correctly — document the before and after.
#
# -->>
#
# ## Genie Agent Testing and Validation
#
# After configuring the Genie Agent, I tested it with several additional business questions to check whether it could generate correct answers and SQL.
#
# The following questions were tested:
#
# 1. **Which customer generated the highest revenue?**
# 2. **Which supplier generated the highest profit?**
# 3. **What is the monthly revenue trend?**
# 4. **Which product generated the most revenue?**
# 5. **Which customer segment has the highest sales?**
#
# I also checked the generated results against the expected SQL logic and results.
#
# The Genie Agent answered these questions correctly, so no further changes to the instructions or sample queries were required.
#
# This testing helped confirm that the Genie Agent was able to understand the TPCH data and answer different business questions correctly.
#
# -->>
# ### Reason for the Correctness of the agent can be the following -
#
# A Genie Agent was created for the TPCH business analytics data and configured to answer business-related questions using natural language.
#
# ### Agent Configuration
#
# The Agent was configured with:
#
# - **Agent Title:** TPCH Business Analytics Genie Agent
# - **Agent Description:** Added a description explaining that the Agent is used for analyzing TPCH sales, customers, orders, products, and revenue data.
# - **Data Sources:** Added the relevant TPCH tables required for the analysis.
# - **SQL Warehouse:** Configured the Agent with the SQL Warehouse for query execution.
# - **Instructions:** Added business rules to guide the Agent while calculating revenue, analyzing customers, products, and sales trends.
# - **Sample Queries:** Added verified SQL examples to help the Agent understand the required joins, calculations, aggregations, and date-based analysis.
# - **Additional Context:** Reviewed the available table and column information so that the Agent could better understand the TPCH data.
#
# ### Testing
#
# After completing the configuration, I tested the Agent with several business questions, including:
#
# 1. Which customer generated the highest revenue?
# 2. Which supplier generated the highest profit?
# 3. What is the monthly revenue trend?
# 4. Which product generated the most revenue?
# 5. Which customer segment has the highest sales?
# 6. Show me the top 5 customers by revenue.
# 7. Which month had the highest revenue?
# 8. Which products generated the highest sales?
# 9. Which customers placed the most orders?
#
# I checked the generated SQL and the returned results for these questions.
#
# The Genie Agent answered the tested questions correctly, so no further changes were required to the instructions or sample queries.
#
# This helped validate that the Agent was properly configured and could understand the TPCH data and answer different business questions using natural language.
