# %% [markdown]
# 1. Create a serverless SQL warehouse and run 3 exploratory queries against a gold table from Day 6/8.
#
# -->>
#
# I have created a SQL warehouse.
#
# ## Exploratory Data Analysis
#
# Using the `cyntexa_dev.silver.sales_silver` table, we performed three exploratory SQL queries to understand the sales data from different perspectives.
#
# ### 1. Product-wise Sales Analysis
# This query shows the total quantity sold and total revenue generated by each product. It helps identify which products are performing better in terms of sales and revenue.
#
# ### 2. Customer-wise Spending Analysis
# This query shows the total number of orders and total amount spent by each customer. It helps identify high-value customers based on their spending.
#
# ### 3. Monthly Sales Trend
# This query groups the sales data by month and calculates the total quantity sold and total revenue for each month. It helps us understand how sales and revenue change over time.
#
# These queries provide a basic understanding of product performance, customer spending, and overall sales trends.

# %% [markdown]
# 2. Build an AI/BI dashboard with at least 2 visualizations sourced from those queries.
#
# -->
#
# ## AI/BI Dashboard
#
# Created an AI/BI dashboard named **day_11_DA_dashboard** using the sales analysis queries.
#
# dashboard url -
#
# ```https://dbc-5900cfd5-17f5.cloud.databricks.com/dashboardsv3/01f1b033062a12e5ad5777dee83dac1d/published?o=7474648669865424```
#
# The dashboard contains three visualizations:
#
# 1. **Revenue by Product** – shows total revenue generated by each product.
# 2. **Top Customers by Spending** – shows the customers with the highest total spending.
# 3. **Monthly Revenue Trend** – shows how revenue changes month by month.
#
# These visualizations help analyze product performance, customer spending, and monthly sales trends in a single dashboard.
#
# ![image_1789449199217.png](./image_1789449199217.png "image_1789449199217.png")

# %% [markdown]
# 3. Publish the dashboard and test the 'Ask Genie' feature with 2 plain-English questions.
#
# -->>
#
# ## Publish Dashboard and Test Ask Genie
#
# The **day_11_DA_dashboard** was published successfully.
#
# The **Ask Genie** feature was tested using the following plain-English questions:
#
# 1. **Which product generated the highest revenue?**
# 2. **Which customer spent the most money?**
#
# Ask Genie was used to get insights from the dashboard data using natural-language questions instead of writing SQL queries.
#
# ![image_1789449098237.png](./image_1789449098237.png "image_1789449098237.png")
